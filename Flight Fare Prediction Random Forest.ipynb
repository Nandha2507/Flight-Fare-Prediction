# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Anaconda7\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Getting the Training and Testing data

# %%
df=pd.read_excel(r"F:\Family\Nandha\ML & DL Projects\Flight-Price-Prediction-master\Data_Train.xlsx")
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df1=pd.read_excel(r"F:\Family\Nandha\ML & DL Projects\Flight-Price-Prediction-master\Test_set.xlsx")
df1.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
df.shape
# Out:
# (10683, 11)

# %%
df1.shape
# Out:
# (2671, 10)

# %% [markdown]
# ### Concatenating Training and Testing Datasets

# %%
data=df.append(df1,sort=False)
data.shape
# Out:
# (13354, 11)

# %%
data.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
data.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# dtype: object

# %% [markdown]
# ### Feature Engineering

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
## First, we will try to split the Date_of_Journey Column into Day month and year as separate columns

data["Day"]=data["Date_of_Journey"].str.split("/").str[0]
data["Month"]=data["Date_of_Journey"].str.split("/").str[1]
data["Year"]=data["Date_of_Journey"].str.split("/").str[2]

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0  24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0   1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0   9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0  12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0  01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# 3    05  2019
# 4    03  2019

# %%
data.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Day                 object
# Month               object
# Year                object
# dtype: object

# %%
### Typecasting

data["Day"]=data["Day"].astype(int)
data["Month"]=data["Month"].astype(int)
data["Year"]=data["Year"].astype(int)

# %%
data.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Day                  int32
# Month                int32
# Year                 int32
# dtype: object

# %%
data=data.drop(['Date_of_Journey'],axis=1)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Day  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24      3
# 1         13:15   7h 25m     2 stops         No info   7662.0    1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0    9      6
# 3         23:30   5h 25m      1 stop         No info   6218.0   12      5
# 4         21:35   4h 45m      1 stop         No info  13302.0    1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
### We can see that The feature Arrival time has some inadequate data in it, So we will try to reorder it.

data["Arrival_Time"]=data["Arrival_Time"].str.split(" ").str[0]

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Day  Month  Year
# 0        01:10   2h 50m    non-stop         No info   3897.0   24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662.0    1      5  2019
# 2        04:25      19h     2 stops         No info  13882.0    9      6  2019
# 3        23:30   5h 25m      1 stop         No info   6218.0   12      5  2019
# 4        21:35   4h 45m      1 stop         No info  13302.0    1      3  2019

# %%
### Now lets check the Missing Values

data.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Day                   0
# Month                 0
# Year                  0
# dtype: int64

# %%
### We can see that the feature Total_stops and route has one null values and Price has 2671 Null values

data["Total_Stops"]=data["Total_Stops"].fillna("1 stop")

# %%
pd.Categorical(data["Total_Stops"])
# Out:
# [non-stop, 2 stops, 2 stops, 1 stop, 1 stop, ..., 1 stop, non-stop, 1 stop, 1 stop, 1 stop]
# Length: 13354
# Categories (5, object): [1 stop, 2 stops, 3 stops, 4 stops, non-stop]

# %%
### We will convert Non stop into 0 Zero

data["Total_Stops"]=data["Total_Stops"].replace('non-stop','0 stops')
data["Total_Stops"]=data["Total_Stops"].replace('1 stop','1 stops')

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Day  Month  Year
# 0        01:10   2h 50m     0 stops         No info   3897.0   24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662.0    1      5  2019
# 2        04:25      19h     2 stops         No info  13882.0    9      6  2019
# 3        23:30   5h 25m     1 stops         No info   6218.0   12      5  2019
# 4        21:35   4h 45m     1 stops         No info  13302.0    1      3  2019

# %%
### We will try to split the Total_Stops into a Numerical Fetaure

data["Stops"]=data["Total_Stops"].str.split(" ").str[0]
data.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Day  Month  \
# 0        01:10   2h 50m     0 stops         No info   3897.0   24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0    1      5
# 2        04:25      19h     2 stops         No info  13882.0    9      6
# 3        23:30   5h 25m     1 stops         No info   6218.0   12      5
# 4        21:35   4h 45m     1 stops         No info  13302.0    1      3
#
#    Year Stops
# 0  2019     0
# 1  2019     2
# 2  2019     2
# 3  2019     1
# 4  2019     1

# %%
## we will convert the Stops feature into Integer datatype

data["Stops"]=data["Stops"].astype(int)

# %%
data.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Day                  int32
# Month                int32
# Year                 int32
# Stops                int32
# dtype: object

# %%
data=data.drop(["Total_Stops"],axis=1)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Additional_Info    Price  Day  Month  Year  Stops
# 0        01:10   2h 50m         No info   3897.0   24      3  2019      0
# 1        13:15   7h 25m         No info   7662.0    1      5  2019      2
# 2        04:25      19h         No info  13882.0    9      6  2019      2
# 3        23:30   5h 25m         No info   6218.0   12      5  2019      1
# 4        21:35   4h 45m         No info  13302.0    1      3  2019      1

# %%
### Now we will to try to split the Arrival time into Arrival hour and Arrival Minutes & Similarly to the Depature_Time

data["Arrival_hr"]=data["Arrival_Time"].str.split(":").str[0]
data["Arrival_min"]=data["Arrival_Time"].str.split(":").str[1]
data["Dep_hr"]=data["Dep_Time"].str.split(":").str[0]
data["Dep_min"]=data["Dep_Time"].str.split(":").str[1]
data=data.drop(["Dep_Time"],axis=1)

# %%
data=data.drop(["Arrival_Time"],axis=1)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Day  Month  Year  Stops Arrival_hr Arrival_min  \
# 0         No info   3897.0   24      3  2019      0         01          10
# 1         No info   7662.0    1      5  2019      2         13          15
# 2         No info  13882.0    9      6  2019      2         04          25
# 3         No info   6218.0   12      5  2019      1         23          30
# 4         No info  13302.0    1      3  2019      1         21          35
#
#   Dep_hr Dep_min
# 0     22      20
# 1     05      50
# 2     09      25
# 3     18      05
# 4     16      50

# %%
### Now lets handle the Route feature.. We will split Each city into Route_1,Route_2,Route_3,Route_4 etc

data["Route_1"]=data["Route"].str.split("→ ").str[0]
data["Route_2"]=data["Route"].str.split("→ ").str[1]
data["Route_3"]=data["Route"].str.split("→ ").str[2]
data["Route_4"]=data["Route"].str.split("→ ").str[3]
data["Route_5"]=data["Route"].str.split("→ ").str[4]
data=data.drop(["Route"],axis=1)

# %%
data.head()
# Out:
#        Airline    Source Destination Duration Additional_Info    Price  Day  \
# 0       IndiGo  Banglore   New Delhi   2h 50m         No info   3897.0   24
# 1    Air India   Kolkata    Banglore   7h 25m         No info   7662.0    1
# 2  Jet Airways     Delhi      Cochin      19h         No info  13882.0    9
# 3       IndiGo   Kolkata    Banglore   5h 25m         No info   6218.0   12
# 4       IndiGo  Banglore   New Delhi   4h 45m         No info  13302.0    1
#
#    Month  Year  Stops Arrival_hr Arrival_min Dep_hr Dep_min Route_1 Route_2  \
# 0      3  2019      0         01          10     22      20    BLR      DEL
# 1      5  2019      2         13          15     05      50    CCU     IXR
# 2      6  2019      2         04          25     09      25    DEL     LKO
# 3      5  2019      1         23          30     18      05    CCU     NAG
# 4      3  2019      1         21          35     16      50    BLR     NAG
#
#   Route_3 Route_4 Route_5
# 0     NaN     NaN     NaN
# 1    BBI      BLR     NaN
# 2    BOM      COK     NaN
# 3     BLR     NaN     NaN
# 4     DEL     NaN     NaN

# %%
data.isnull().sum()
# Out:
# Airline                0
# Source                 0
# Destination            0
# Duration               0
# Additional_Info        0
# Price               2671
# Day                    0
# Month                  0
# Year                   0
# Stops                  0
# Arrival_hr             0
# Arrival_min            0
# Dep_hr                 0
# Dep_min                0
# Route_1                1
# Route_2                1
# Route_3             4341
# Route_4            11397
# Route_5            13296
# dtype: int64

# %%
### We will replace the null values of the price column by filling the mean Values

data["Price"].fillna(data["Price"].mean(),inplace=True)

# %%
### We can also replace the Nan values of Route_1,Route_2,Route_3,Route_4.Route_5 by a category called None

data["Route_1"].fillna("None",inplace=True)
data["Route_2"].fillna("None",inplace=True)
data["Route_3"].fillna("None",inplace=True)
data["Route_4"].fillna("None",inplace=True)
data["Route_5"].fillna("None",inplace=True)

# %%
data.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Duration           0
# Additional_Info    0
# Price              0
# Day                0
# Month              0
# Year               0
# Stops              0
# Arrival_hr         0
# Arrival_min        0
# Dep_hr             0
# Dep_min            0
# Route_1            0
# Route_2            0
# Route_3            0
# Route_4            0
# Route_5            0
# dtype: int64

# %%
data=data.drop(["Duration"],axis=1)
data.head()
# Out:
#        Airline    Source Destination Additional_Info    Price  Day  Month  \
# 0       IndiGo  Banglore   New Delhi         No info   3897.0   24      3
# 1    Air India   Kolkata    Banglore         No info   7662.0    1      5
# 2  Jet Airways     Delhi      Cochin         No info  13882.0    9      6
# 3       IndiGo   Kolkata    Banglore         No info   6218.0   12      5
# 4       IndiGo  Banglore   New Delhi         No info  13302.0    1      3
#
#    Year  Stops Arrival_hr Arrival_min Dep_hr Dep_min Route_1 Route_2 Route_3  \
# 0  2019      0         01          10     22      20    BLR      DEL    None
# 1  2019      2         13          15     05      50    CCU     IXR     BBI
# 2  2019      2         04          25     09      25    DEL     LKO     BOM
# 3  2019      1         23          30     18      05    CCU     NAG      BLR
# 4  2019      1         21          35     16      50    BLR     NAG      DEL
#
#   Route_4 Route_5
# 0    None    None
# 1     BLR    None
# 2     COK    None
# 3    None    None
# 4    None    None

# %%
### Let encode the Categorical feature Airline,Source,Destination,Additional_Info,Route_1,Route_2,Route_3,Route_4 and 
### Route_5 into Numerical features

from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data["Airline"]=encoder.fit_transform(data["Airline"])
data["Source"]=encoder.fit_transform(data["Source"])
data["Destination"]=encoder.fit_transform(data["Destination"])
data["Additional_Info"]=encoder.fit_transform(data["Additional_Info"])
data["Route_1"]=encoder.fit_transform(data["Route_1"])
data["Route_2"]=encoder.fit_transform(data["Route_2"])
data["Route_3"]=encoder.fit_transform(data["Route_3"])
data["Route_4"]=encoder.fit_transform(data["Route_4"])
data["Route_5"]=encoder.fit_transform(data["Route_5"])

# %%
data.head()
# Out:
#    Airline  Source  Destination  Additional_Info    Price  Day  Month  Year  \
# 0        3       0            5                8   3897.0   24      3  2019
# 1        1       3            0                8   7662.0    1      5  2019
# 2        4       2            1                8  13882.0    9      6  2019
# 3        3       3            0                8   6218.0   12      5  2019
# 4        3       0            5                8  13302.0    1      3  2019
#
#    Stops Arrival_hr Arrival_min Dep_hr Dep_min  Route_1  Route_2  Route_3  \
# 0      0         01          10     22      20        0       13       24
# 1      2         13          15     05      50        2       25        1
# 2      2         04          25     09      25        3       32        4
# 3      1         23          30     18      05        2       34        3
# 4      1         21          35     16      50        0       34        8
#
#    Route_4  Route_5
# 0       12        4
# 1        3        4
# 2        5        4
# 3       12        4
# 4       12        4

# %% [markdown]
# ### Feature Selection

# %%
X=data.drop(["Price"],axis=1)

# %%
X.head()
# Out:
#    Airline  Source  Destination  Additional_Info  Day  Month  Year  Stops  \
# 0        3       0            5                8   24      3  2019      0
# 1        1       3            0                8    1      5  2019      2
# 2        4       2            1                8    9      6  2019      2
# 3        3       3            0                8   12      5  2019      1
# 4        3       0            5                8    1      3  2019      1
#
#   Arrival_hr Arrival_min Dep_hr Dep_min  Route_1  Route_2  Route_3  Route_4  \
# 0         01          10     22      20        0       13       24       12
# 1         13          15     05      50        2       25        1        3
# 2         04          25     09      25        3       32        4        5
# 3         23          30     18      05        2       34        3       12
# 4         21          35     16      50        0       34        8       12
#
#    Route_5
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
y=data["Price"]
y.head()
# Out:
# 0     3897.0
# 1     7662.0
# 2    13882.0
# 3     6218.0
# 4    13302.0
# Name: Price, dtype: float64

# %%
X.shape
# Out:
# (13354, 17)

# %%
y.shape
# Out:
# (13354,)

# %%
### Splitting Data into Train and test data

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %% [markdown]
# ### Random Forest Regessor

# %%
### First we will apply the Hyperparameter optimization using Randamized Search CV

from sklearn.model_selection import RandomizedSearchCV
## The n_estimators is the total number of trees 
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
## Max_depth is the maximum depth of the tree
max_depth=[int(x) for x in np.linspace(start=5,stop=30,num=6)]
## Min_samples_split is the minimum number of samples to split an internal Node
min_samples_split=[2,5,10,20,100]
## Min_samples_leaf is the samples requires to be a leaf node
min_samples_leaf=[1,2,5,10]
## Max_features is the Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']

# %%
ran_grid={'n_estimators':n_estimators,
         'max_depth':max_depth,
         'min_samples_split':min_samples_split,
         'min_samples_leaf':min_samples_leaf,
         'max_features':max_features}

# %%
print(ran_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 20, 100], 'min_samples_leaf': [1, 2, 5, 10], 'max_features': ['auto', 'sqrt', 'log2']}

# %%
### First we will import Random Forest regressor and Use hyper paramter Optimization using Randomized Search and lets 
### Fit the Model

from sklearn.ensemble import RandomForestRegressor
rf= RandomForestRegressor()

# %%
### Random search of parameters, using 3 fold cross validation, 
### search across 50 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = ran_grid,scoring='neg_mean_squared_error', n_iter = 50,
                               cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.6s
# [CV] n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.5s remaining:    0.0s
# [CV]  n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.7s
# [CV] n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   3.6s
# [CV] n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   4.1s
# [CV] n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   4.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5, total=   3.4s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5, total=   3.4s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5, total=   3.5s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5, total=   3.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=5, total=   3.5s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  18.0s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  15.0s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  14.4s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  14.3s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  14.6s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  11.3s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  12.0s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  11.7s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  11.6s
# [CV] n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1000, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  11.8s
# [CV] n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5, total=   4.9s
# [CV] n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5, total=   4.8s
# [CV] n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5, total=   3.3s
# [CV] n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5, total=   3.3s
# [CV] n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=5, total=   3.7s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20, total=  10.3s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20, total=  13.6s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20, total=  11.9s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20, total=  12.9s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=20, total=  11.5s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   6.0s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   5.4s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   5.3s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   6.9s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=30, total=   5.7s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   9.3s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   9.1s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   9.2s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   9.6s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   8.9s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25, total=  26.4s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25, total=  29.1s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25, total=  30.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25, total=  28.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=25, total=  26.1s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  29.5s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  29.1s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  28.6s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  29.0s
# [CV] n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=700, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=20, total=  29.7s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=  10.5s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=  10.0s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=  10.4s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=  10.8s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=10, total=  11.6s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30, total=  26.6s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30, total=  27.0s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30, total=  26.0s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30, total=  26.3s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=auto, max_depth=30, total=  24.3s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20, total=  29.3s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20, total=  29.7s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20, total=  29.4s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20, total=  29.1s
# [CV] n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=100, min_samples_leaf=2, max_features=auto, max_depth=20, total=  32.8s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  24.9s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  23.9s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  21.8s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  22.3s
# [CV] n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20
# [CV]  n_estimators=600, min_samples_split=5, min_samples_leaf=5, max_features=auto, max_depth=20, total=  21.3s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20, total=  21.4s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20, total=  21.5s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20, total=  21.4s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20, total=  22.5s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=1, max_features=log2, max_depth=20, total=  24.4s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=  38.0s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=  39.3s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=  40.4s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=  37.6s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=  42.9s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=  12.2s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=  13.2s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=  10.9s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=  10.6s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=sqrt, max_depth=25, total=  11.1s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   8.3s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   8.7s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   7.8s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   7.4s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   8.1s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=  10.7s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=  11.1s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=  10.8s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=  10.7s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=30, total=  11.1s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10, total=   1.4s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10, total=   1.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10, total=   1.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10, total=   1.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=10, total=   1.2s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  10.6s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  11.1s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  13.7s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  11.1s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=  11.2s
# [CV] n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=  17.0s
# [CV] n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=  17.8s
# [CV] n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=  14.8s
# [CV] n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=  14.1s
# [CV] n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=20, min_samples_leaf=10, max_features=sqrt, max_depth=25, total=  14.0s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10, total=  12.2s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10, total=  11.1s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10, total=  12.0s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10, total=  11.9s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=10, max_features=log2, max_depth=10, total=  11.4s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=   3.8s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=   3.6s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=   3.6s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=   3.4s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=   3.6s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25, total=  12.3s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25, total=  13.5s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25, total=  13.7s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25, total=  14.8s
# [CV] n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25
# [CV]  n_estimators=1100, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=25, total=  15.4s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30, total=  13.4s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30, total=  15.6s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30, total=  12.1s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30, total=  11.1s
# [CV] n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30
# [CV]  n_estimators=800, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=30, total=  11.8s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20, total=  13.8s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20, total=  13.0s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20, total=  14.6s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20, total=  19.9s
# [CV] n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20
# [CV]  n_estimators=700, min_samples_split=2, min_samples_leaf=2, max_features=log2, max_depth=20, total=  15.0s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.5s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.6s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.5s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   3.3s
# [CV] n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   3.8s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=  15.1s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=  15.4s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   9.7s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   9.8s
# [CV] n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=   9.2s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   4.6s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   4.3s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   4.2s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   4.5s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   4.4s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   7.9s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   8.2s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   7.9s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   8.4s
# [CV] n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=100, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=   8.3s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25, total=  15.6s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25, total=  16.6s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25, total=  24.2s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25, total=  17.1s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=25, total=  20.1s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=  15.1s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=  11.3s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=  11.6s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=  11.8s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=1, max_features=sqrt, max_depth=30, total=  12.4s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=  17.3s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=  19.1s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=  18.1s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=  18.1s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=10, total=  16.4s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15, total=  11.2s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15, total=  11.1s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15, total=  11.6s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15, total=  14.5s
# [CV] n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=300, min_samples_split=20, min_samples_leaf=5, max_features=auto, max_depth=15, total=  14.5s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=  28.3s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=  28.3s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=  34.2s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=  26.0s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=  23.4s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   3.4s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   3.1s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.9s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.9s
# [CV] n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   2.8s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=  15.3s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=  30.7s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=  25.5s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=  26.2s
# [CV] n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=2, min_samples_leaf=10, max_features=auto, max_depth=15, total=  26.5s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=  27.1s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=  32.4s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=  28.9s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=  37.5s
# [CV] n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15
# [CV]  n_estimators=800, min_samples_split=20, min_samples_leaf=2, max_features=log2, max_depth=15, total=  38.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  23.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  18.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  20.5s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  24.0s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  20.9s
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5, total= 1.0min
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5, total= 1.1min
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5, total= 1.1min
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5, total= 1.1min
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=5, total= 1.0min
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  48.5s
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  46.7s
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  49.6s
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  52.3s
# [CV] n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=1100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=10, total=  45.7s
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15, total= 2.2min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15, total= 2.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15, total= 1.1min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15, total=  45.1s
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=5, max_features=auto, max_depth=15, total=  36.4s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=  10.1s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=   9.8s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=  10.4s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=  10.6s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=5, max_features=auto, max_depth=15, total=  10.2s
# [CV] n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30, total=  17.2s
# [CV] n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30, total=  18.0s
# [CV] n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30, total=  18.3s
# [CV] n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30, total=  18.2s
# [CV] n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=30, total=  16.8s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=  12.6s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=  13.1s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=  13.0s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=  12.9s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=  12.4s
# [CV] n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15, total=  13.2s
# [CV] n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15, total=  13.8s
# [CV] n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15, total=  13.9s
# [CV] n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15, total=  14.5s
# [CV] n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15
# [CV]  n_estimators=400, min_samples_split=20, min_samples_leaf=1, max_features=auto, max_depth=15, total=  13.4s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25, total=   3.8s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25, total=   3.8s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25, total=   3.7s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25, total=   4.0s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=log2, max_depth=25, total=   3.8s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25, total=  17.7s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25, total=  17.6s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25, total=  18.0s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25, total=  17.8s
# [CV] n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=25, total=  17.9s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30, total=   7.6s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30, total=   6.9s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30, total=   7.2s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30, total=   7.0s
# [CV] n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30
# [CV]  n_estimators=300, min_samples_split=2, min_samples_leaf=1, max_features=log2, max_depth=30, total=   7.2s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed: 72.6min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators='warn',
#                                                    n_jobs=None, oob_score=False,
#                                                    random_sta...
#                    iid='warn', n_iter=50, n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 20,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
y_pred=rf_random.predict(X_test)

# %%
rf_random.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#                       max_features='log2', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=5,
#                       min_weight_fraction_leaf=0.0, n_estimators=1200,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1200,
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': 20}

# %%
rfu=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
                      max_features='log2', max_leaf_nodes=None,
                      min_impurity_decrease=0.0, min_impurity_split=None,
                      min_samples_leaf=1, min_samples_split=5,
                      min_weight_fraction_leaf=0.0, n_estimators=1200,
                      n_jobs=None, oob_score=False, random_state=None,

                          verbose=0, warm_start=False)

# %%
sns.distplot(y_test-y_pred)

# %%
from sklearn.metrics import r2_score

score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.6412745665160804
